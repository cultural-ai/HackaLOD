# %%
import pandas as pd

# %%
pd1=pd.read_csv(
        "./data/hyperreal2.csv", encoding="latin1")
pd2=pd.read_csv(
        "./data/hyperreal_with_concept_labels.csv", encoding="latin1")

# %%
pd1
# Out:
#                                      symbol           concept  \
# 0                                    aMGPDT     theVirginMary
# 1                                   cacalia         adulation
# 2                                cactusWren           arizona
# 3      cadencyLabelsOfTheBritishRoyalFamily  theUnitedKingdom
# 4                                  caducues        paxGoddess
# ...                                     ...               ...
# 41905                          yellowCarpet              rank
# 41906                            yellowFlag           disease
# 41907                          yellowJasper             charm
# 41908                          yellowJasper             charm
# 41909                          yellowJasper             charm
#
#                contexts                types
# 0             christian  AttributeSimulation
# 1        flowerLanguage           Simulation
# 2      generalOrUnknown           Simulation
# 3      generalOrUnknown           Simulation
# 4                 roman           Simulation
# ...                 ...                  ...
# 41905           islamic           Simulation
# 41906  generalOrUnknown           Simulation
# 41907  generalOrUnknown           Simulation
# 41908  generalOrUnknown           Simulation
# 41909  generalOrUnknown           Simulation
#
# [41910 rows x 4 columns]

# %%
pd2[pd2.concept=="fertility"]
# Out:
#      Unnamed: 0              symbol    concept                   contexts  \
# 553         553            cauldron  fertility           generalOrUnknown
# 554         554                 axe  fertility           generalOrUnknown
# 555         555               ember  fertility           generalOrUnknown
# 556         556                stag  fertility  celtic @ generalOrUnknown
# 557         557               gourd  fertility           generalOrUnknown
# ..          ...                 ...        ...                        ...
# 816         816       serpentWreath  fertility                     celtic
# 817         817  sevenCowsWithABull  fertility                   egyptian
# 818         818             phrygia  fertility           generalOrUnknown
# 819         819             twoFish  fertility                   egyptian
# 820         820          woodpecker  fertility           generalOrUnknown
#
#           types      label
# 553  Simulation  fertility
# 554  Simulation  fertility
# 555  Simulation  fertility
# 556  Simulation  fertility
# 557  Simulation  fertility
# ..          ...        ...
# 816  Simulation  fertility
# 817  Simulation  fertility
# 818  Simulation  fertility
# 819  Simulation  fertility
# 820  Simulation  fertility
#
# [268 rows x 6 columns]
